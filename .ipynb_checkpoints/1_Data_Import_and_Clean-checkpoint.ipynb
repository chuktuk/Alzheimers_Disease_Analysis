# %% [markdown]
# # Data Import, Exploration, and Cleaning

# %% [markdown]
# ## ADNIMERGE Table from ADNI
# - Datasource [ADNI website](http://adni.loni.usc.edu/data-samples/access-data/)
# - Documentation
# > Data used in the preparation of this article were obtained from the Alzheimer’s Disease
# Neuroimaging Initiative (ADNI) database (adni.loni.usc.edu). The ADNI was launched in
# 2003 as a public-private partnership, led by Principal Investigator Michael W. Weiner,
# MD. The primary goal of ADNI has been to test whether serial magnetic resonance imaging
# (MRI), positron emission tomography (PET), other biological markers, and clinical and
# neuropsychological assessment can be combined to measure the progression of mild
# cognitive impairment (MCI) and early Alzheimer’s disease (AD). For up-to-date information,
# see www.adni-info.org.

# %%
# import the relevant packages

import pandas as pd
import matplotlib.pyplot as plt

# run cell magics
# %matplotlib inline

# %%
# starting with object dtype to avoid errors in data consistency

adni_full = pd.read_csv('ADNIMERGE.csv', dtype='object')

# %%
adni_full.head()
# Out:
#   RID        PTID VISCODE SITE COLPROT ORIGPROT   EXAMDATE DX_bl   AGE  \
# 0   2  011_S_0002      bl   11   ADNI1    ADNI1   9/8/2005    CN  74.3
# 1   3  011_S_0003      bl   11   ADNI1    ADNI1  9/12/2005    AD  81.3
# 2   3  011_S_0003     m06   11   ADNI1    ADNI1  3/13/2006    AD  81.3
# 3   3  011_S_0003     m12   11   ADNI1    ADNI1  9/12/2006    AD  81.3
# 4   3  011_S_0003     m24   11   ADNI1    ADNI1  9/12/2007    AD  81.3
#
#   PTGENDER  ... TAU_bl PTAU_bl   FDG_bl PIB_bl AV45_bl  Years_bl Month_bl  \
# 0     Male  ...    NaN     NaN  1.36665    NaN     NaN         0        0
# 1     Male  ...  239.7   22.83  1.08355    NaN     NaN         0        0
# 2     Male  ...  239.7   22.83  1.08355    NaN     NaN  0.498289  5.96721
# 3     Male  ...  239.7   22.83  1.08355    NaN     NaN  0.999316  11.9672
# 4     Male  ...  239.7   22.83  1.08355    NaN     NaN   1.99863  23.9344
#
#   Month   M update_stamp
# 0     0   0      58:27.0
# 1     0   0      58:27.0
# ...

# %%
# 14036 rows

adni_full.shape
# Out:
# (14036, 113)

# %%
# view each column to check out datatypes
# examine which columns are needed based on suggestions from the tadpole challenge

# commenting out to save space 
# adni_full.info

# %%
adni_full.DX.value_counts()
# Out:
# MCI         4410
# CN          3310
# Dementia    2230
# Name: DX, dtype: int64

# %%
# research online for logical order of categories

DX = ['CN', 'MCI', 'Dementia']

# %%
adni_full.DX_bl.value_counts()
# Out:
# LMCI    4886
# CN      4233
# EMCI    2553
# AD      1600
# SMC      741
# Name: DX_bl, dtype: int64

# %%
# research online for logical order of categories

DX_bl = ['CN', 'SMC', 'EMCI', 'LMCI', 'AD']

# %%
# initialize empty dataframe

adni = pd.DataFrame()

# %%
# set important datatypes

adni['RID'] = adni_full.RID.astype('int')
adni['EXAMDATE'] = pd.to_datetime(adni_full['EXAMDATE'])
adni['EXAMDATE_bl'] = pd.to_datetime(adni_full['EXAMDATE_bl'])
adni['Month'] = adni_full.Month.astype('int')
adni['PTGENDER'] = pd.Categorical(adni_full.PTGENDER)
adni['DX'] = pd.Categorical(adni_full.DX, ordered=True, categories=DX)
adni['DX_bl'] = pd.Categorical(adni_full.DX_bl, ordered=True, categories=DX_bl)
adni['PTEDUCAT'] = adni_full.PTEDUCAT.astype('int')

# %%
# can't convert to floats  ['ABETA', 'TAU', 'PTAU']
# create a list of values that should be float dtype for quick looping

floats = ['AGE', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate', 'Hippocampus', 
          'Ventricles', 'WholeBrain', 'Entorhinal', 'MidTemp', 'FDG', 'AV45']

# %%
# use list to convert dtypes to float and move to new df

for i in floats:
    adni[i] = adni_full[i].astype('float')
    
    # age has no baseline '_bl' equivalent
    if i == 'AGE':
        continue
    
    # every other column has a '_bl' equivalent to convert as well
    else:    
        y = i + '_bl'
        adni[y] = adni_full[y].astype('float')

# %%
# examine the new dataframe

# comment out to save space
# adni.info

# %%
cols = list(adni.columns.values)

# %%
# generate NaN report

# add column names
nan_dict = {'column_name': list(cols)}

# initialze temp lists for looping
pct_list = []
sum_list = []

# generate a list of the pct null values
for col in cols:
    pct_list.append(adni[col].isnull().mean())
    sum_list.append(adni[col].isnull().sum())
    

# assign lists to the dictionary
nan_dict['pct_missing'] = pct_list
nan_dict['sum_missing'] = sum_list

# convert to dataframe
nan_report = pd.DataFrame(nan_dict)

# %%
nan_report
# Out:
#            column_name  pct_missing  sum_missing
# 0                  RID     0.000000            0
# 1             EXAMDATE     0.000000            0
# 2          EXAMDATE_bl     0.000000            0
# 3                Month     0.000000            0
# 4             PTGENDER     0.000000            0
# 5                   DX     0.291109         4086
# 6                DX_bl     0.001639           23
# 7             PTEDUCAT     0.000000            0
# 8                  AGE     0.000142            2
# 9                CDRSB     0.283200         3975
# 10            CDRSB_bl     0.000000            0
# 11              ADAS11     0.291821         4096
# 12           ADAS11_bl     0.002280           32
# 13              ADAS13     0.298447         4189
# 14           ADAS13_bl     0.006911           97
# 15                MMSE     0.288900         4055
# 16             MMSE_bl     0.000000            0
# 17     RAVLT_immediate     0.297592         4177
# ...

# %%
# drop all columns missing too much data

adni.drop(labels=['FDG', 'FDG_bl', 'AV45', 'AV45_bl'], axis='columns', inplace=True)

# %%
#adni.columns

# %%
# include the examdate in the index

adni.set_index([adni.RID, adni.EXAMDATE], inplace=True)

# %%
adni.sort_index(inplace=True)

# %%
adni.drop(['RID', 'EXAMDATE'], axis='columns', inplace=True)

# %%
adni
# Out:
#                 EXAMDATE_bl  Month PTGENDER        DX DX_bl  PTEDUCAT   AGE  \
# RID  EXAMDATE
# 2    2005-09-08  2005-09-08      0     Male        CN    CN        16  74.3
#      2006-03-06  2005-09-08      6     Male        CN    CN        16  74.3
#      2008-08-27  2005-09-08     36     Male        CN    CN        16  74.3
#      2010-09-22  2005-09-08     60     Male        CN    CN        16  74.3
#      2011-03-04  2005-09-08     66     Male       NaN    CN        16  74.3
#      2011-09-19  2005-09-08     72     Male        CN    CN        16  74.3
#      2012-03-22  2005-09-08     78     Male       NaN    CN        16  74.3
#      2012-09-26  2005-09-08     84     Male       MCI    CN        16  74.3
#      2013-03-25  2005-09-08     90     Male       NaN    CN        16  74.3
#      2013-09-09  2005-09-08     96     Male        CN    CN        16  74.3
#      2014-03-17  2005-09-08    102     Male       NaN    CN        16  74.3
# ...

# %%
adni.head(20)
# Out:
#                EXAMDATE_bl  Month PTGENDER        DX DX_bl  PTEDUCAT   AGE  \
# RID EXAMDATE
# 2   2005-09-08  2005-09-08      0     Male        CN    CN        16  74.3
#     2006-03-06  2005-09-08      6     Male        CN    CN        16  74.3
#     2008-08-27  2005-09-08     36     Male        CN    CN        16  74.3
#     2010-09-22  2005-09-08     60     Male        CN    CN        16  74.3
#     2011-03-04  2005-09-08     66     Male       NaN    CN        16  74.3
#     2011-09-19  2005-09-08     72     Male        CN    CN        16  74.3
#     2012-03-22  2005-09-08     78     Male       NaN    CN        16  74.3
#     2012-09-26  2005-09-08     84     Male       MCI    CN        16  74.3
#     2013-03-25  2005-09-08     90     Male       NaN    CN        16  74.3
#     2013-09-09  2005-09-08     96     Male        CN    CN        16  74.3
#     2014-03-17  2005-09-08    102     Male       NaN    CN        16  74.3
# ...

# %%
# check for missing diagnoses

adni.DX.isnull().mean()
# Out:
# 0.2911085779424337

# %%
# check for missing diagnoses

adni.DX_bl.isnull().mean()
# Out:
# 0.0016386434881732687

# %%
# drop all rows missing a diagnosis DX or baseline diagnosis

adni_dx = adni.dropna(subset=['DX', 'DX_bl'])

# %%
# verify the drop results

adni_dx.DX.isnull().sum()
# Out:
# 0

# %%
# verify the drop results

adni_dx.DX_bl.isnull().sum()
# Out:
# 0

# %%
# check the new df shape for number of rows

adni_dx.shape
# Out:
# (9950, 27)

# %%
# separate into clinical data and scans

# %%
# isolate clinical data

clinical = adni_dx.loc[:, 'EXAMDATE_bl':'RAVLT_immediate_bl']

# %%
clinical.shape
# Out:
# (9950, 17)

# %%
# check the number of rows (visits) with complete clinical data

clinical_rmv = clinical.dropna(how='any')

# %%
clinical_rmv.shape
# Out:
# (9524, 17)

# %%
# only include patients with multiple visits that have complete data

# generate a count of exams for each patient
num_clin_exams = clinical_rmv.groupby('RID')['EXAMDATE_bl'].count()

# reduce this list to patients with multiple visits
clin_filter = num_clin_exams[num_clin_exams > 1]

# filter the clinical data to these patients
clin_data = clinical_rmv.loc[clin_filter.index]

# %%
clin_data.shape
# Out:
# (9072, 17)

# %%
# 9072 visits where the patient has multiple visits, with no missing data

clin_data.head()
# Out:
#                EXAMDATE_bl  Month PTGENDER  DX DX_bl  PTEDUCAT   AGE  CDRSB  \
# RID EXAMDATE
# 2   2005-09-08  2005-09-08      0     Male  CN    CN        16  74.3    0.0
#     2006-03-06  2005-09-08      6     Male  CN    CN        16  74.3    0.0
#     2008-08-27  2005-09-08     36     Male  CN    CN        16  74.3    0.0
#     2010-09-22  2005-09-08     60     Male  CN    CN        16  74.3    0.0
#     2011-09-19  2005-09-08     72     Male  CN    CN        16  74.3    0.0
#
#                 CDRSB_bl  ADAS11  ADAS11_bl  ADAS13  ADAS13_bl  MMSE  MMSE_bl  \
# RID EXAMDATE
# 2   2005-09-08       0.0   10.67      10.67   18.67      18.67  28.0     28.0
#     2006-03-06       0.0   10.67      10.67   19.67      18.67  28.0     28.0
#     2008-08-27       0.0   12.00      10.67   20.00      18.67  29.0     28.0
#     2010-09-22       0.0   14.00      10.67   23.00      18.67  28.0     28.0
#     2011-09-19       0.0   12.00      10.67   21.00      18.67  23.0     28.0
#
# ...

# %%
# create a dataframe of scans and check for complete data

# include only the scan data
scans = adni_dx.loc[:, 'Hippocampus':]

# add EXAMDATE_bl back in
scans['EXAMDATE_bl'] = adni_dx.EXAMDATE_bl

# filter for complete rows
scans_rmv = scans.dropna(how='any')

# %%
scans_rmv.shape
# Out:
# (5006, 11)

# %%
# down to 5006 rows, check for the number with multiple visits

# generate a count of exams for each patient
num_scan_exams = scans_rmv.groupby('RID')['EXAMDATE_bl'].count()

# reduce this list to patients with multiple visits
scan_filter = num_scan_exams[num_scan_exams > 1]

# filter the clinical data to these patients
scan_data = scans_rmv.loc[scan_filter.index]

# %%
scan_data.shape
# Out:
# (4822, 11)

# %%
# 4822 complete rows, where the patient had multiple visits

scan_data.head()
# Out:
#                 Hippocampus  Hippocampus_bl  Ventricles  Ventricles_bl  \
# RID EXAMDATE
# 3   2005-09-12       5319.0          5319.0     84599.0        84599.0
#     2006-03-13       5446.0          5319.0     88580.0        84599.0
#     2006-09-12       5157.0          5319.0     90099.0        84599.0
#     2007-09-12       5139.0          5319.0     97420.0        84599.0
# 4   2005-11-08       6869.0          6869.0     39605.0        39605.0
#
#                 WholeBrain  WholeBrain_bl  Entorhinal  Entorhinal_bl  MidTemp  \
# RID EXAMDATE
# 3   2005-09-12   1129830.0      1129830.0      1791.0         1791.0  18422.0
#     2006-03-13   1100060.0      1129830.0      2427.0         1791.0  16972.0
#     2006-09-12   1095640.0      1129830.0      1596.0         1791.0  17330.0
#     2007-09-12   1088560.0      1129830.0      1175.0         1791.0  16398.0
# 4   2005-11-08   1154980.0      1154980.0      3983.0         3983.0  19615.0
#
#                 MidTemp_bl EXAMDATE_bl
# ...

# %%
# do a quick examination for outliers in clinical data

clin_data.loc[:,'PTEDUCAT':].plot(kind='box', rot=90)

# %%
# do a quick examination for outliers on scan data (whole brain on different scale)

scan_data.loc[:,['Hippocampus', 'Hippocampus_bl', 'Ventricles', 'Ventricles_bl',
                'Entorhinal', 'Entorhinal_bl', 'MidTemp', 'MidTemp_bl']].plot(kind='box', rot=90)

# %%
scan_data.loc[:, 'WholeBrain':'WholeBrain_bl'].plot(kind='box')
